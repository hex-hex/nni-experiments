# %%
import os
import datetime
import json
import sqlite3

# %%
experiments_record = {}

# %%
for root,directories, files in os.walk('../nni'):
    for file in files:
        file_name = '{}/{}'.format(root,file)
        if 'log' in file_name or 'run.sh' in file_name or 'stderr' in file_name:
            continue
        meta_data = file_name.split('/')
        experiment_id = meta_data[3]
        trial_id = meta_data[5]
        file_type = meta_data[-1]
        parse_dict = {
            'state': parse_state,
            'metrics': parse_metrics,
            'parameter.cfg': parse_parameters,
            'nni.sqlite': parse_sqlite,
        }
        file_data = parse_dict.get(file_type, print)(file_name)
        experiments_record[experiment_id] = experiments_record.get(experiment_id, {})
        if 'sqlite' not in trial_id:
            experiments_record[experiment_id]['trials'] = experiments_record[experiment_id].get('trials', [])
            trial_index = [i for i, v in enumerate(experiments_record[experiment_id]['trials']) if v.get('trial_id', '') == trial_id]
            if not trail_index:
                experiments_record[experiment_id]['trials'].append({'trial_id': trial_id})
                trial_index = len(experiments_record[experiment_id]['trials']) - 1
            else:
                trial_index = trial_index[0]
        else:
            tunner_info = { **file_data.get('advisor', {}), **file_data.get('tuner', {})}
            method_name = [v for k,v in tunner_info.items() if 'builtin' in k][0]
            experiments_record[experiment_id]['method'] = method_name
# Out:
# ../nni/experiments/MrUaVQmO/trials/QQD7j/.nni/metrics

# %%
def parse_state(file_name: str):
    with open(file_name, 'r') as f:
        time_stamp = int(f.readlines()[0].split(' ')[-1]) / 1000.0
        exp_time = datetime.datetime.fromtimestamp(time_stamp)
        return {'trial_time': exp_time}
def parse_metrics(file_name: str):
    with open(file_name, 'r') as f:
        content = f.read()
        file_head = content.split('{')[0]
        try:
            metric_details =  json.loads(content.replace(file_head, ''))
            return {
                'metric_id':file_head,
                **metric_details
            }
        except json.JSONDecodeError:
            print(file_name)
            print(content)
            return {}
def parse_parameters(file_name: str):
    with open(file_name, 'r') as f:
        content = f.read()
        return {k:v for k,v in json.loads(content).items()}
def parse_sqlite(file_name:str):
    try:
        conn = sqlite3.connect(file_name)
        c = conn.cursor()
        c.execute(' SELECT * FROM ExperimentProfile')
        result = c.fetchall()
    finally:
        conn.close()
    return json.loads(result[0][0])

# %%
[{
    'experiments_id': k,
    'trail_id': k_t,
    'value': v_t['value']
    'detail': v_t
 } for k,v in experiments_record.items() for k_t, v_t in v.items()]
# Out:
# [{'experiments_id': 'MrUaVQmO',
#   'trail_id': 'uP3yN',
#   'detail': {'parameter_id': '3_0_17',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 64,
#     'regularizer': -6.729313973543235,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'uP3yN',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 31, 17, 35000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'fVoiq',
#   'detail': {'parameter_id': '3_0_16',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 64,
#     'regularizer': -7.019839301588759,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'fVoiq',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 29, 56, 754000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'FGyC0',
#   'detail': {'parameter_id': '3_0_26',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 256,
#     'hidden_factors': 4,
#     'regularizer': -6.607342731053954,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'FGyC0',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6771000027656555',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 24, 33, 143000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'jVwyB',
#   'detail': {'parameter_id': '3_1_24',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -7.227287733459015,
#     'TRIAL_BUDGET': 3},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'jVwyB',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7500749826431274',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 43, 0, 956000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'iE6dZ',
#   'detail': {'parameter_id': '3_0_23',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 4,
#     'regularizer': -7.331167676115004,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'iE6dZ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7208999991416931',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 8, 6, 593000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'W7HQ3',
#   'detail': {'parameter_id': '3_0_15',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 16,
#     'regularizer': -6.6882494692555206,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'W7HQ3',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 28, 36, 517000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'G7gmu',
#   'detail': {'parameter_id': '3_0_12',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 8,
#     'regularizer': -5.857694313117297,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'G7gmu',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7469000220298767',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 21, 35, 927000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'IrEVo',
#   'detail': {'parameter_id': '3_0_24',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -7.227287733459015,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'IrEVo',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7548750042915344',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 17, 25, 365000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'pEE9z',
#   'detail': {'parameter_id': '3_1_11',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -7.8724841997682145,
#     'TRIAL_BUDGET': 3},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'pEE9z',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7507249712944031',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 33, 41, 887000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'M7kZB',
#   'detail': {'parameter_id': '3_0_19',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 4,
#     'regularizer': -4.443566767117796,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'M7kZB',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7208499908447266',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 48, 13, 219000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'w1Zey',
#   'detail': {'parameter_id': '3_0_3',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 1024,
#     'hidden_factors': 32,
#     'regularizer': -6.754749207371489,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'w1Zey',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49912500381469727',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 51, 6, 347000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'KUJca',
#   'detail': {'parameter_id': '3_0_1',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 1024,
#     'hidden_factors': 8,
#     'regularizer': -6.233733150147672,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'KUJca',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49950000643730164',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 47, 32, 263000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'KAlfJ',
#   'detail': {'parameter_id': '3_0_18',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -4.487496373857571,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'KAlfJ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7523499727249146',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 40, 25, 653000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'qv8eA',
#   'detail': {'parameter_id': '3_0_9',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 16,
#     'regularizer': -5.288373502994335,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'qv8eA',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 2, 34, 790000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'J06s9',
#   'detail': {'parameter_id': '3_0_4',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 128,
#     'regularizer': -4.749582185937283,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'J06s9',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 52, 42, 347000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'cVove',
#   'detail': {'parameter_id': '3_0_25',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 512,
#     'hidden_factors': 16,
#     'regularizer': -4.8682155192732495,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'cVove',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5775499939918518',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 20, 10, 944000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'mCALU',
#   'detail': {'parameter_id': '3_0_7',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 4,
#     'regularizer': -7.804307085591946,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'mCALU',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 59, 28, 302000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'hwCrB',
#   'detail': {'parameter_id': '3_0_13',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 32,
#     'regularizer': -4.103449472545696,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'hwCrB',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 22, 54, 469000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'UaozP',
#   'detail': {'parameter_id': '3_0_21',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -7.00045271406702,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'UaozP',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7520250082015991',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 58, 48, 447000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'nLfYm',
#   'detail': {'parameter_id': '3_0_10',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 1024,
#     'hidden_factors': 32,
#     'regularizer': -4.724186410469656,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'nLfYm',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.499099999666214',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 4, 27, 28000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'rNdpH',
#   'detail': {'parameter_id': '3_0_14',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 256,
#     'hidden_factors': 8,
#     'regularizer': -4.319320164407095,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'rNdpH',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6959999799728394',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 27, 21, 186000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'QQD7j',
#   'detail': {'parameter_id': '3_1_18',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -4.487496373857571,
#     'TRIAL_BUDGET': 3}}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'giogK',
#   'detail': {'parameter_id': '3_0_8',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 1024,
#     'hidden_factors': 16,
#     'regularizer': -7.623236465959419,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'giogK',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49924999475479126',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 1, 13, 953000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'IR8uP',
#   'detail': {'parameter_id': '3_0_11',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 128,
#     'regularizer': -7.8724841997682145,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'IR8uP',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7559750080108643',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 13, 42, 342000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 's4on2',
#   'detail': {'parameter_id': '3_0_6',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 512,
#     'hidden_factors': 4,
#     'regularizer': -7.789259319625488,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000114',
#    'trial_job_id': 's4on2',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5609999895095825',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 58, 12, 170000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'G4D11',
#   'detail': {'parameter_id': '3_0_20',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 128,
#     'regularizer': -5.9374635024316404,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'G4D11',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 18, 49, 44, 698000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'nwxKc',
#   'detail': {'parameter_id': '3_0_0',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 512,
#     'hidden_factors': 8,
#     'regularizer': -4.533964178200936,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'nwxKc',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5722249746322632',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 45, 46, 263000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'OE8TI',
#   'detail': {'parameter_id': '3_0_22',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 2048,
#     'hidden_factors': 64,
#     'regularizer': -7.9527041564051215,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'OE8TI',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 30, 19, 0, 13, 984000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'wWWyl',
#   'detail': {'parameter_id': '3_0_5',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 512,
#     'hidden_factors': 4,
#     'regularizer': -4.915223779749642,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'wWWyl',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5617750287055969',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 55, 24, 379000)}},
#  {'experiments_id': 'MrUaVQmO',
#   'trail_id': 'XF4ZS',
#   'detail': {'parameter_id': '3_0_2',
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 1024,
#     'hidden_factors': 8,
#     'regularizer': -6.65824850674083,
#     'TRIAL_BUDGET': 1},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'XF4ZS',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49985000491142273',
#    'trial_time': datetime.datetime(2020, 6, 30, 17, 49, 21, 927000)}},
#  {'experiments_id': 'MrUaVQmO', 'trail_id': 'method', 'detail': 'BOHB'},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'HpQOl',
#   'detail': {'parameter_id': 2,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 128, 'regularizer': -6},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'HpQOl',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7207000255584717',
#    'trial_time': datetime.datetime(2020, 6, 30, 22, 37, 53, 497000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'UJjd7',
#   'detail': {'parameter_id': 26,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8, 'batch': 128, 'regularizer': -7},
#    'parameter_index': 0,
#    'metric_id': 'ME000107',
#    'trial_job_id': 'UJjd7',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.74795001745224',
#    'trial_time': datetime.datetime(2020, 7, 1, 0, 0, 15, 857000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'HvxId',
#   'detail': {'parameter_id': 1,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 128, 'regularizer': -7},
#    'parameter_index': 0,
#    'metric_id': 'ME000107',
#    'trial_job_id': 'HvxId',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.719124972820282',
#    'trial_time': datetime.datetime(2020, 6, 30, 22, 30, 2, 711000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'ddn4V',
#   'detail': {'parameter_id': 7,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 256, 'regularizer': -6},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'ddn4V',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6747000217437744',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 6, 44, 951000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'KSBwW',
#   'detail': {'parameter_id': 3,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 128, 'regularizer': -5},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'KSBwW',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7158750295639038',
#    'trial_time': datetime.datetime(2020, 6, 30, 22, 45, 44, 363000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'UYkOZ',
#   'detail': {'parameter_id': 16,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 1024, 'regularizer': -7},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'UYkOZ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4994249939918518',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 32, 47, 331000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'JkSxi',
#   'detail': {'parameter_id': 17,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 1024, 'regularizer': -6},
#    'parameter_index': 0,
#    'metric_id': 'ME000110',
#    'trial_job_id': 'JkSxi',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49982500076293945',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 34, 33, 443000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'fwiuR',
#   'detail': {'parameter_id': 22,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 2048, 'regularizer': -6},
#    'parameter_index': 0,
#    'metric_id': 'ME000110',
#    'trial_job_id': 'fwiuR',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49732500314712524',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 41, 49, 628000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'P7dAB',
#   'detail': {'parameter_id': 15,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 1024, 'regularizer': -8},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'P7dAB',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5005999803543091',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 30, 59, 565000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'cNgPW',
#   'detail': {'parameter_id': 29,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8, 'batch': 128, 'regularizer': -4},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'cNgPW',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7331500053405762',
#    'trial_time': datetime.datetime(2020, 7, 1, 0, 23, 39, 234000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'yaa5Z',
#   'detail': {'parameter_id': 13,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 512, 'regularizer': -5},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'yaa5Z',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5583249926567078',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 26, 24, 130000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'v4qp8',
#   'detail': {'parameter_id': 10,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 512, 'regularizer': -8},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'v4qp8',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5618249773979187',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 18, 16, 187000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'YWEcU',
#   'detail': {'parameter_id': 6,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 256, 'regularizer': -7},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'YWEcU',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6770750284194946',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 2, 23, 549000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'uVtzl',
#   'detail': {'parameter_id': 14,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 512, 'regularizer': -4},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'uVtzl',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5481250286102295',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 29, 10, 928000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'IFRjl',
#   'detail': {'parameter_id': 19,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 1024, 'regularizer': -4},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'IFRjl',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4991999864578247',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 38, 3, 544000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'xnPtN',
#   'detail': {'parameter_id': 18,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 1024, 'regularizer': -5},
#    'parameter_index': 0,
#    'metric_id': 'ME000110',
#    'trial_job_id': 'xnPtN',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49869999289512634',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 36, 19, 120000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'WCgIU',
#   'detail': {'parameter_id': 9,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 256, 'regularizer': -4},
#    'parameter_index': 0,
#    'metric_id': 'ME000107',
#    'trial_job_id': 'WCgIU',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.666100025177002',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 15, 32, 176000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'mHlUn',
#   'detail': {'parameter_id': 28,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8, 'batch': 128, 'regularizer': -5},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'mHlUn',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7461000084877014',
#    'trial_time': datetime.datetime(2020, 7, 1, 0, 15, 48, 950000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'iSUHd',
#   'detail': {'parameter_id': 11,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 512, 'regularizer': -7},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'iSUHd',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5596250295639038',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 20, 55, 769000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'j1uHZ',
#   'detail': {'parameter_id': 23,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 2048, 'regularizer': -5},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'j1uHZ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4975999891757965',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 43, 4, 944000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'bNpAC',
#   'detail': {'parameter_id': 8,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 256, 'regularizer': -5},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'bNpAC',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6718999743461609',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 11, 6, 557000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'Pi8WZ',
#   'detail': {'parameter_id': 20,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 2048, 'regularizer': -8},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'Pi8WZ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4972499907016754',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 39, 19, 885000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'wH2QP',
#   'detail': {'parameter_id': 27,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8, 'batch': 128, 'regularizer': -6},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'wH2QP',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7438250184059143',
#    'trial_time': datetime.datetime(2020, 7, 1, 0, 8, 3, 12000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'AIoA6',
#   'detail': {'parameter_id': 4,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 128, 'regularizer': -4},
#    'parameter_index': 0,
#    'metric_id': 'ME000107',
#    'trial_job_id': 'AIoA6',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.699999988079071',
#    'trial_time': datetime.datetime(2020, 6, 30, 22, 53, 34, 719000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'HBk72',
#   'detail': {'parameter_id': 24,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 2048, 'regularizer': -4},
#    'parameter_index': 0,
#    'metric_id': 'ME000110',
#    'trial_job_id': 'HBk72',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49732500314712524',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 44, 19, 910000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'pGl7g',
#   'detail': {'parameter_id': 12,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 512, 'regularizer': -6},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'pGl7g',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5608999729156494',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 23, 35, 714000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'mVMIs',
#   'detail': {'parameter_id': 0,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 128, 'regularizer': -8},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'mVMIs',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7131999731063843',
#    'trial_time': datetime.datetime(2020, 6, 30, 22, 22, 11, 573000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'tc6Rq',
#   'detail': {'parameter_id': 5,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 256, 'regularizer': -8},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'tc6Rq',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6725999712944031',
#    'trial_time': datetime.datetime(2020, 6, 30, 22, 57, 59, 628000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'XDTO9',
#   'detail': {'parameter_id': 21,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4, 'batch': 2048, 'regularizer': -7},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'XDTO9',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4972749948501587',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 40, 34, 767000)}},
#  {'experiments_id': 'DOR2vzi7',
#   'trail_id': 'Q2h3V',
#   'detail': {'parameter_id': 25,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8, 'batch': 128, 'regularizer': -8},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'Q2h3V',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7488250136375427',
#    'trial_time': datetime.datetime(2020, 6, 30, 23, 52, 17, 819000)}},
#  {'experiments_id': 'DOR2vzi7', 'trail_id': 'method', 'detail': 'BatchTuner'},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'eEs5W',
#   'detail': {'parameter_id': 9,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 1024,
#     'regularizer': -5.277681090235147},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'eEs5W',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4994249939918518',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 26, 49, 69000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'ra163',
#   'detail': {'parameter_id': 19,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 256,
#     'regularizer': -7.0162031722185905},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'ra163',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.708549976348877',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 10, 53, 769000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'ZKEKc',
#   'detail': {'parameter_id': 14,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -5.256353413807377},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'ZKEKc',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7541000247001648',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 48, 44, 957000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'eBTMf',
#   'detail': {'parameter_id': 26,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 128,
#     'regularizer': -4.6891578714648405},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'eBTMf',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.746025025844574',
#    'trial_time': datetime.datetime(2020, 6, 18, 20, 8, 27, 501000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'T0nsF',
#   'detail': {'parameter_id': 17,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -6.4501974738358605},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'T0nsF',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7468249797821045',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 3, 41, 705000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'p8Yto',
#   'detail': {'parameter_id': 3,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 1024,
#     'regularizer': -6.276284578283236},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'p8Yto',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5005999803543091',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 12, 46, 833000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'HTgjo',
#   'detail': {'parameter_id': 15,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 256,
#     'regularizer': -6.902832061833168},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'HTgjo',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7112249732017517',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 53, 59, 447000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'mz4K4',
#   'detail': {'parameter_id': 11,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 128,
#     'regularizer': -4.987201151636715},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'mz4K4',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7514749765396118',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 37, 31, 179000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'j9Fn6',
#   'detail': {'parameter_id': 22,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -4.016150724119961},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'j9Fn6',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7355250120162964',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 35, 45, 875000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'eWMbj',
#   'detail': {'parameter_id': 12,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 1024,
#     'regularizer': -4.502230528421942},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'eWMbj',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4988499879837036',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 39, 14, 930000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'BfxeZ',
#   'detail': {'parameter_id': 24,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 128,
#     'regularizer': -5.030447854504121},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'BfxeZ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.746874988079071',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 51, 58, 556000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'scJJC',
#   'detail': {'parameter_id': 7,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 2048,
#     'regularizer': -5.409193140915201},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'scJJC',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 21, 43, 826000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'eHJGE',
#   'detail': {'parameter_id': 28,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -5.710206228389935},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'eHJGE',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7521250247955322',
#    'trial_time': datetime.datetime(2020, 6, 18, 20, 24, 26, 68000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'pxYot',
#   'detail': {'parameter_id': 8,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 512,
#     'regularizer': -6.227432929985914},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'pxYot',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5803499817848206',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 24, 39, 867000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'iEkak',
#   'detail': {'parameter_id': 2,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 1024,
#     'regularizer': -7.153127327850729},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'iEkak',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5000500082969666',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 10, 58, 123000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'FdLig',
#   'detail': {'parameter_id': 27,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 128,
#     'regularizer': -5.139135383637258},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'FdLig',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7145249843597412',
#    'trial_time': datetime.datetime(2020, 6, 18, 20, 16, 15, 440000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'y15Hj',
#   'detail': {'parameter_id': 4,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 2048,
#     'regularizer': -7.933872159308012},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'y15Hj',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 14, 23, 709000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'rjgcY',
#   'detail': {'parameter_id': 25,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 128,
#     'regularizer': -5.898986908370127},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'rjgcY',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7474250197410583',
#    'trial_time': datetime.datetime(2020, 6, 18, 20, 0, 31, 97000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'WZ5jb',
#   'detail': {'parameter_id': 16,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 2048,
#     'regularizer': -7.3456753506856804},
#    'parameter_index': 0,
#    'metric_id': 'ME000110',
#    'trial_job_id': 'WZ5jb',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 55, 35, 770000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'BwRPF',
#   'detail': {'parameter_id': 5,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 2048,
#     'regularizer': -7.622853940517352},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'BwRPF',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 15, 39, 55000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'jTh9C',
#   'detail': {'parameter_id': 10,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 512,
#     'regularizer': -6.940963059106183},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'jTh9C',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5791500210762024',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 29, 30, 844000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'eAIVL',
#   'detail': {'parameter_id': 13,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 2048,
#     'regularizer': -7.3912184059452475},
#    'parameter_index': 0,
#    'metric_id': 'ME000110',
#    'trial_job_id': 'eAIVL',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 40, 33, 565000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'zJIfW',
#   'detail': {'parameter_id': 1,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 2048,
#     'regularizer': -7.227329328266639},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'zJIfW',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 9, 10, 456000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'PvQH0',
#   'detail': {'parameter_id': 29,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -5.765633915767145},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'PvQH0',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7507749795913696',
#    'trial_time': datetime.datetime(2020, 6, 18, 20, 32, 33, 734000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'wL2Sz',
#   'detail': {'parameter_id': 23,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -5.6098668031894245},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'wL2Sz',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7478500008583069',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 43, 58, 105000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'BJ8cT',
#   'detail': {'parameter_id': 0,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 512,
#     'regularizer': -5.6942521974322275},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'BJ8cT',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5766749978065491',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 7, 49, 882000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'IvIwx',
#   'detail': {'parameter_id': 20,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 128,
#     'regularizer': -4.716099685163577},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'IvIwx',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.748324990272522',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 19, 25, 506000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'L5p6F',
#   'detail': {'parameter_id': 21,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 128,
#     'regularizer': -5.001269160173696},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'L5p6F',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7508999705314636',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 27, 30, 272000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'PLDaJ',
#   'detail': {'parameter_id': 18,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 512,
#     'regularizer': -4.25774515629543},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'PLDaJ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5545499920845032',
#    'trial_time': datetime.datetime(2020, 6, 18, 19, 6, 23, 217000)}},
#  {'experiments_id': 'lsUAFSIx',
#   'trail_id': 'wsdxk',
#   'detail': {'parameter_id': 6,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 256,
#     'regularizer': -7.141269871075899},
#    'parameter_index': 0,
#    'metric_id': 'ME000107',
#    'trial_job_id': 'wsdxk',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.703000009059906',
#    'trial_time': datetime.datetime(2020, 6, 18, 18, 20, 7, 605000)}},
#  {'experiments_id': 'lsUAFSIx', 'trail_id': 'method', 'detail': 'TPE'},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'G7JEP',
#   'detail': {'parameter_id': 12,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 256,
#     'regularizer': -6.446970591247208},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'G7JEP',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7045999765396118',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 59, 33, 661000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'hKjLO',
#   'detail': {'parameter_id': 5,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 256,
#     'regularizer': -6.443608827819348},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'hKjLO',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7037249803543091',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 30, 32, 823000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'TPKNG',
#   'detail': {'parameter_id': 19,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 256,
#     'regularizer': -7.545010871540998},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'TPKNG',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6663249731063843',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 28, 27, 782000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'FCzpX',
#   'detail': {'parameter_id': 25,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 512,
#     'regularizer': -6.057780481342814},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'FCzpX',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5589500069618225',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 57, 16, 844000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'bReTn',
#   'detail': {'parameter_id': 13,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 256,
#     'regularizer': -4.106604112948044},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'bReTn',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6937999725341797',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 4, 45, 186000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'pxLeo',
#   'detail': {'parameter_id': 7,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 512,
#     'regularizer': -7.68899458554848},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'pxLeo',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5824750065803528',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 38, 17, 430000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'ipK8X',
#   'detail': {'parameter_id': 8,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 1024,
#     'regularizer': -4.645177380926976},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'ipK8X',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49927499890327454',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 40, 8, 955000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'PQkD1',
#   'detail': {'parameter_id': 23,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 512,
#     'regularizer': -6.331174009003565},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'PQkD1',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5832499861717224',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 47, 50, 330000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'QBY7M',
#   'detail': {'parameter_id': 24,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 256,
#     'regularizer': -7.241134365417633},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'QBY7M',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7080000042915344',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 53, 32, 92000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'wHR8E',
#   'detail': {'parameter_id': 16,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 256,
#     'regularizer': -6.443608826323963},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'wHR8E',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7038249969482422',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 14, 27, 330000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'pgPGI',
#   'detail': {'parameter_id': 0,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 1024,
#     'regularizer': -4.983021084298285},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'pgPGI',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4991999864578247',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 14, 58, 314000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'IIFmv',
#   'detail': {'parameter_id': 2,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 256,
#     'regularizer': -5.061765914236831},
#    'parameter_index': 0,
#    'metric_id': 'ME000107',
#    'trial_job_id': 'IIFmv',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.674049973487854',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 21, 13, 274000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'jrSoQ',
#   'detail': {'parameter_id': 28,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 1024,
#     'regularizer': -4.889968916176047},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'jrSoQ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.499099999666214',
#    'trial_time': datetime.datetime(2020, 6, 30, 15, 11, 8, 876000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'rpQrP',
#   'detail': {'parameter_id': 22,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 1024,
#     'regularizer': -4.430972809578201},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'rpQrP',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.499099999666214',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 43, 36, 951000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'uWntp',
#   'detail': {'parameter_id': 21,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 512,
#     'regularizer': -5.94007543052725},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'uWntp',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5601750016212463',
#    'trial_time': datetime.datetime(2020, 6, 30, 14, 40, 45, 244000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'H6y3V',
#   'detail': {'parameter_id': 10,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 256,
#     'regularizer': -6.443593034627601},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'H6y3V',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7076249718666077',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 49, 35, 258000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'Uvmsb',
#   'detail': {'parameter_id': 3,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 1024,
#     'regularizer': -5.9012718833201685},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'Uvmsb',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4994499981403351',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 23, 22, 102000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'HlJJ7',
#   'detail': {'parameter_id': 27,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 128,
#     'regularizer': -6.927988391216237},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'HlJJ7',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7195249795913696',
#    'trial_time': datetime.datetime(2020, 6, 30, 15, 8, 16, 557000)}},
#  {'experiments_id': 'fd50fhVE',
#   'trail_id': 'YZRRP',
#   'detail': {'parameter_id': 6,
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 256,
#     'regularizer': -6.5655986449155685},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'YZRRP',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6765249967575073',
#    'trial_time': datetime.datetime(2020, 6, 30, 13, 34, 55, 575000)}},
# ...
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.579800009727478',
#    'trial_time': datetime.datetime(2020, 6, 26, 8, 11, 36, 882000)}},
#  {'experiments_id': 'uRB7YVHl',
#   'trail_id': 'l5zBq',
#   'detail': {'parameter_id': 13,
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 4,
#     'regularizer': -7.740932995830129},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'l5zBq',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7220500111579895',
#    'trial_time': datetime.datetime(2020, 6, 26, 8, 57, 19, 385000)}},
#  {'experiments_id': 'uRB7YVHl',
#   'trail_id': 'vnJQB',
#   'detail': {'parameter_id': 5,
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 16,
#     'regularizer': -7.67655924401766},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'vnJQB',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7513250112533569',
#    'trial_time': datetime.datetime(2020, 6, 26, 8, 4, 27, 36000)}},
#  {'experiments_id': 'uRB7YVHl',
#   'trail_id': 'uxnUc',
#   'detail': {'parameter_id': 25,
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 128,
#     'hidden_factors': 8,
#     'regularizer': -6.514559304853233},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'uxnUc',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7407249808311462',
#    'trial_time': datetime.datetime(2020, 6, 26, 10, 28, 21, 991000)}},
#  {'experiments_id': 'uRB7YVHl',
#   'trail_id': 'zUUHH',
#   'detail': {'parameter_id': 6,
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 256,
#     'hidden_factors': 8,
#     'regularizer': -5.8898477809764005},
#    'parameter_index': 0,
#    'metric_id': 'ME000108',
#    'trial_job_id': 'zUUHH',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7020750045776367',
#    'trial_time': datetime.datetime(2020, 6, 26, 8, 8, 47, 556000)}},
#  {'experiments_id': 'uRB7YVHl',
#   'trail_id': 'weWJZ',
#   'detail': {'parameter_id': 15,
#    'parameter_source': 'algorithm',
#    'parameters': {'batch': 512,
#     'hidden_factors': 64,
#     'regularizer': -4.638264725983002},
#    'parameter_index': 0,
#    'metric_id': 'ME000109',
#    'trial_job_id': 'weWJZ',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5770000219345093',
#    'trial_time': datetime.datetime(2020, 6, 26, 9, 8, 43, 834000)}},
#  {'experiments_id': 'uRB7YVHl', 'trail_id': 'method', 'detail': 'SMAC'},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'IufvK',
#   'detail': {'parameter_id': '3_0_11',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 1024,
#     'regularizer': -4.038445739942965,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'IufvK',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49904999136924744',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 18, 1, 578000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'bqHcA',
#   'detail': {'parameter_id': '3_0_21',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 1024,
#     'regularizer': -4.9909617739833285,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'bqHcA',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4994499981403351',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 54, 54, 131000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'Jo61h',
#   'detail': {'parameter_id': '3_0_2',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 512,
#     'regularizer': -4.7644652667474485,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'Jo61h',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5774499773979187',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 35, 34, 318000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'VzYfc',
#   'detail': {'parameter_id': '3_0_19',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 512,
#     'regularizer': -4.478880271679854,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'VzYfc',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5739750266075134',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 48, 6, 668000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'JavVX',
#   'detail': {'parameter_id': '3_0_0',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 256,
#     'regularizer': -5.566295384494289,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'JavVX',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6979249715805054',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 24, 53, 335000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'RMHeM',
#   'detail': {'parameter_id': '3_0_25',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 2048,
#     'regularizer': -7.350540123602229,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'RMHeM',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 11, 57, 479000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'mgqhC',
#   'detail': {'parameter_id': '3_0_23',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -6.544888962161331,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'mgqhC',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7489500045776367',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 7, 46, 963000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'beoOs',
#   'detail': {'parameter_id': '3_0_20',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 256,
#     'regularizer': -7.39729694816263,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'beoOs',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7059000134468079',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 52, 44, 733000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'SLKOM',
#   'detail': {'parameter_id': '3_0_16',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 512,
#     'regularizer': -7.07794828208956,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'SLKOM',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5801249742507935',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 39, 0, 715000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'ZPqKx',
#   'detail': {'parameter_id': '3_0_3',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 1024,
#     'regularizer': -5.20756883131941,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'ZPqKx',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.4995749890804291',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 37, 20, 477000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'vOPtr',
#   'detail': {'parameter_id': '3_0_14',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 1024,
#     'regularizer': -7.849682461523765,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'vOPtr',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49947500228881836',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 28, 2, 467000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'ICyWz',
#   'detail': {'parameter_id': '3_0_1',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 128,
#     'regularizer': -5.75601215292621,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'ICyWz',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7106750011444092',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 32, 45, 946000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'Gdh6P',
#   'detail': {'parameter_id': '3_0_18',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 256,
#     'regularizer': -6.826976860764622,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'Gdh6P',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6998000144958496',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 45, 22, 212000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'hl8t9',
#   'detail': {'parameter_id': '3_0_13',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 512,
#     'regularizer': -5.657831767766204,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'hl8t9',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5781000256538391',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 25, 56, 696000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'wC9Up',
#   'detail': {'parameter_id': '3_0_26',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 2048,
#     'regularizer': -7.5305080589536395,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'wC9Up',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49729999899864197',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 13, 17, 187000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'h6Vor',
#   'detail': {'parameter_id': '3_0_10',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 128,
#     'regularizer': -5.970181205726924,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'h6Vor',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7039250135421753',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 15, 52, 380000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'PFTFD',
#   'detail': {'parameter_id': '3_1_15',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 128,
#     'regularizer': -6.53636292880725,
#     'TRIAL_BUDGET': 6},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'PFTFD',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7512500286102295',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 38, 25, 561000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'ovqD8',
#   'detail': {'parameter_id': '3_0_8',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 8,
#     'batch': 512,
#     'regularizer': -7.122842973685762,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'ovqD8',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5776000022888184',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 3, 43, 741000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'eWeR6',
#   'detail': {'parameter_id': '3_0_6',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 256,
#     'regularizer': -4.247366341033548,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'eWeR6',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6998500227928162',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 59, 4, 893000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'vXS6r',
#   'detail': {'parameter_id': '3_0_17',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 1024,
#     'regularizer': -4.147633159499687,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000116',
#    'trial_job_id': 'vXS6r',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49892500042915344',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 40, 57, 505000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'f8ctG',
#   'detail': {'parameter_id': '3_0_5',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 128,
#     'regularizer': -4.879489830103262,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'f8ctG',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7511249780654907',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 54, 36, 858000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'lfTek',
#   'detail': {'parameter_id': '3_0_7',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 1024,
#     'regularizer': -5.510920470674347,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'lfTek',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.49927499890327454',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 1, 1, 850000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'zIDya',
#   'detail': {'parameter_id': '3_0_4',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -6.690079311085734,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000113',
#    'trial_job_id': 'zIDya',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.751800000667572',
#    'trial_time': datetime.datetime(2020, 6, 26, 12, 45, 27, 79000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'AFF5e',
#   'detail': {'parameter_id': '3_0_24',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 512,
#     'regularizer': -4.114175589877679,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'AFF5e',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.5709499716758728',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 10, 33, 912000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'OZ5VH',
#   'detail': {'parameter_id': '3_0_9',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 4,
#     'batch': 256,
#     'regularizer': -7.92139658378178,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000112',
#    'trial_job_id': 'OZ5VH',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.67330002784729',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 8, 6, 256000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'HCKEE',
#   'detail': {'parameter_id': '3_0_15',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 16,
#     'batch': 128,
#     'regularizer': -6.53636292880725,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'HCKEE',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7508500218391418',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 36, 1, 407000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'R2Ita',
#   'detail': {'parameter_id': '3_0_22',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 64,
#     'batch': 256,
#     'regularizer': -4.2114730419336155,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'R2Ita',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.6951500177383423',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 59, 39, 601000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'YZFbY',
#   'detail': {'parameter_id': '3_0_12',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 256,
#     'regularizer': -6.702665700143166,
#     'TRIAL_BUDGET': 2},
#    'metric_id': 'ME000115',
#    'trial_job_id': 'YZFbY',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7105749845504761',
#    'trial_time': datetime.datetime(2020, 6, 26, 13, 23, 12, 754000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'TDSw3',
#   'detail': {'parameter_id': '3_1_4',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 32,
#     'batch': 128,
#     'regularizer': -6.690079311085734,
#     'TRIAL_BUDGET': 6},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'TDSw3',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7490749955177307',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 21, 20, 417000)}},
#  {'experiments_id': 'SreqCz44',
#   'trail_id': 'WVDEn',
#   'detail': {'parameter_id': '3_1_5',
#    'parameter_source': 'algorithm',
#    'parameters': {'hidden_factors': 128,
#     'batch': 128,
#     'regularizer': -4.879489830103262,
#     'TRIAL_BUDGET': 6},
#    'metric_id': 'ME000114',
#    'trial_job_id': 'WVDEn',
#    'type': 'FINAL',
#    'sequence': 0,
#    'value': '0.7528499960899353',
#    'trial_time': datetime.datetime(2020, 6, 26, 14, 30, 32, 437000)}},
#  {'experiments_id': 'SreqCz44', 'trail_id': 'method', 'detail': 'Hyperband'}]

# %%
experiments_record
# Out:
# {'MrUaVQmO': {'trials': [{'trial_id': 'uP3yN'},
#    {'trial_id': 'uP3yN'},
#    {'trial_id': 'uP3yN'},
#    {'trial_id': 'fVoiq'},
#    {'trial_id': 'fVoiq'},
#    {'trial_id': 'fVoiq'},
#    {'trial_id': 'FGyC0'},
#    {'trial_id': 'FGyC0'},
#    {'trial_id': 'FGyC0'},
#    {'trial_id': 'jVwyB'},
#    {'trial_id': 'jVwyB'},
#    {'trial_id': 'jVwyB'},
#    {'trial_id': 'iE6dZ'},
#    {'trial_id': 'iE6dZ'},
#    {'trial_id': 'iE6dZ'},
#    {'trial_id': 'W7HQ3'},
#    {'trial_id': 'W7HQ3'},
#    {'trial_id': 'W7HQ3'},
#    {'trial_id': 'G7gmu'},
#    {'trial_id': 'G7gmu'},
#    {'trial_id': 'G7gmu'},
#    {'trial_id': 'IrEVo'},
#    {'trial_id': 'IrEVo'},
#    {'trial_id': 'IrEVo'},
#    {'trial_id': 'pEE9z'},
#    {'trial_id': 'pEE9z'},
#    {'trial_id': 'pEE9z'},
#    {'trial_id': 'M7kZB'},
#    {'trial_id': 'M7kZB'},
#    {'trial_id': 'M7kZB'},
#    {'trial_id': 'w1Zey'},
#    {'trial_id': 'w1Zey'},
#    {'trial_id': 'w1Zey'},
#    {'trial_id': 'KUJca'},
#    {'trial_id': 'KUJca'},
#    {'trial_id': 'KUJca'},
#    {'trial_id': 'KAlfJ'},
#    {'trial_id': 'KAlfJ'},
#    {'trial_id': 'KAlfJ'},
#    {'trial_id': 'qv8eA'},
#    {'trial_id': 'qv8eA'},
#    {'trial_id': 'qv8eA'},
#    {'trial_id': 'J06s9'},
#    {'trial_id': 'J06s9'},
#    {'trial_id': 'J06s9'},
#    {'trial_id': 'cVove'},
#    {'trial_id': 'cVove'},
#    {'trial_id': 'cVove'},
#    {'trial_id': 'mCALU'},
#    {'trial_id': 'mCALU'},
#    {'trial_id': 'mCALU'},
#    {'trial_id': 'hwCrB'},
#    {'trial_id': 'hwCrB'},
#    {'trial_id': 'hwCrB'},
#    {'trial_id': 'UaozP'},
#    {'trial_id': 'UaozP'},
#    {'trial_id': 'UaozP'},
#    {'trial_id': 'nLfYm'},
#    {'trial_id': 'nLfYm'},
#    {'trial_id': 'nLfYm'},
#    {'trial_id': 'rNdpH'},
#    {'trial_id': 'rNdpH'},
#    {'trial_id': 'rNdpH'},
#    {'trial_id': 'QQD7j'},
#    {'trial_id': 'QQD7j'},
#    {'trial_id': 'giogK'},
#    {'trial_id': 'giogK'},
#    {'trial_id': 'giogK'},
#    {'trial_id': 'IR8uP'},
#    {'trial_id': 'IR8uP'},
#    {'trial_id': 'IR8uP'},
#    {'trial_id': 's4on2'},
#    {'trial_id': 's4on2'},
#    {'trial_id': 's4on2'},
#    {'trial_id': 'G4D11'},
#    {'trial_id': 'G4D11'},
#    {'trial_id': 'G4D11'},
#    {'trial_id': 'nwxKc'},
#    {'trial_id': 'nwxKc'},
#    {'trial_id': 'nwxKc'},
#    {'trial_id': 'OE8TI'},
#    {'trial_id': 'OE8TI'},
#    {'trial_id': 'OE8TI'},
#    {'trial_id': 'wWWyl'},
#    {'trial_id': 'wWWyl'},
#    {'trial_id': 'wWWyl'},
#    {'trial_id': 'XF4ZS'},
#    {'trial_id': 'XF4ZS'},
#    {'trial_id': 'XF4ZS'}],
#   'method': 'BOHB'},
#  'DOR2vzi7': {'trials': [{'trial_id': 'HpQOl'},
#    {'trial_id': 'HpQOl'},
#    {'trial_id': 'HpQOl'},
#    {'trial_id': 'UJjd7'},
#    {'trial_id': 'UJjd7'},
#    {'trial_id': 'UJjd7'},
#    {'trial_id': 'HvxId'},
#    {'trial_id': 'HvxId'},
#    {'trial_id': 'HvxId'},
#    {'trial_id': 'ddn4V'},
#    {'trial_id': 'ddn4V'},
#    {'trial_id': 'ddn4V'},
#    {'trial_id': 'KSBwW'},
#    {'trial_id': 'KSBwW'},
#    {'trial_id': 'KSBwW'},
#    {'trial_id': 'UYkOZ'},
#    {'trial_id': 'UYkOZ'},
#    {'trial_id': 'UYkOZ'},
#    {'trial_id': 'JkSxi'},
#    {'trial_id': 'JkSxi'},
#    {'trial_id': 'JkSxi'},
#    {'trial_id': 'fwiuR'},
#    {'trial_id': 'fwiuR'},
#    {'trial_id': 'fwiuR'},
#    {'trial_id': 'P7dAB'},
#    {'trial_id': 'P7dAB'},
#    {'trial_id': 'P7dAB'},
#    {'trial_id': 'cNgPW'},
#    {'trial_id': 'cNgPW'},
#    {'trial_id': 'cNgPW'},
#    {'trial_id': 'yaa5Z'},
#    {'trial_id': 'yaa5Z'},
#    {'trial_id': 'yaa5Z'},
#    {'trial_id': 'v4qp8'},
#    {'trial_id': 'v4qp8'},
#    {'trial_id': 'v4qp8'},
#    {'trial_id': 'YWEcU'},
#    {'trial_id': 'YWEcU'},
#    {'trial_id': 'YWEcU'},
#    {'trial_id': 'uVtzl'},
#    {'trial_id': 'uVtzl'},
#    {'trial_id': 'uVtzl'},
#    {'trial_id': 'IFRjl'},
#    {'trial_id': 'IFRjl'},
#    {'trial_id': 'IFRjl'},
#    {'trial_id': 'xnPtN'},
#    {'trial_id': 'xnPtN'},
#    {'trial_id': 'xnPtN'},
#    {'trial_id': 'WCgIU'},
#    {'trial_id': 'WCgIU'},
#    {'trial_id': 'WCgIU'},
#    {'trial_id': 'mHlUn'},
#    {'trial_id': 'mHlUn'},
#    {'trial_id': 'mHlUn'},
#    {'trial_id': 'iSUHd'},
#    {'trial_id': 'iSUHd'},
#    {'trial_id': 'iSUHd'},
#    {'trial_id': 'j1uHZ'},
#    {'trial_id': 'j1uHZ'},
#    {'trial_id': 'j1uHZ'},
#    {'trial_id': 'bNpAC'},
#    {'trial_id': 'bNpAC'},
#    {'trial_id': 'bNpAC'},
#    {'trial_id': 'Pi8WZ'},
#    {'trial_id': 'Pi8WZ'},
#    {'trial_id': 'Pi8WZ'},
#    {'trial_id': 'wH2QP'},
#    {'trial_id': 'wH2QP'},
#    {'trial_id': 'wH2QP'},
#    {'trial_id': 'AIoA6'},
#    {'trial_id': 'AIoA6'},
#    {'trial_id': 'AIoA6'},
#    {'trial_id': 'HBk72'},
#    {'trial_id': 'HBk72'},
#    {'trial_id': 'HBk72'},
#    {'trial_id': 'pGl7g'},
#    {'trial_id': 'pGl7g'},
#    {'trial_id': 'pGl7g'},
#    {'trial_id': 'mVMIs'},
#    {'trial_id': 'mVMIs'},
#    {'trial_id': 'mVMIs'},
#    {'trial_id': 'tc6Rq'},
#    {'trial_id': 'tc6Rq'},
#    {'trial_id': 'tc6Rq'},
#    {'trial_id': 'XDTO9'},
#    {'trial_id': 'XDTO9'},
#    {'trial_id': 'XDTO9'},
#    {'trial_id': 'Q2h3V'},
#    {'trial_id': 'Q2h3V'},
#    {'trial_id': 'Q2h3V'}],
#   'method': 'BatchTuner'},
#  'lsUAFSIx': {'trials': [{'trial_id': 'eEs5W'},
#    {'trial_id': 'eEs5W'},
#    {'trial_id': 'eEs5W'},
#    {'trial_id': 'ra163'},
#    {'trial_id': 'ra163'},
#    {'trial_id': 'ra163'},
#    {'trial_id': 'ZKEKc'},
#    {'trial_id': 'ZKEKc'},
#    {'trial_id': 'ZKEKc'},
#    {'trial_id': 'eBTMf'},
#    {'trial_id': 'eBTMf'},
#    {'trial_id': 'eBTMf'},
#    {'trial_id': 'T0nsF'},
#    {'trial_id': 'T0nsF'},
#    {'trial_id': 'T0nsF'},
#    {'trial_id': 'p8Yto'},
#    {'trial_id': 'p8Yto'},
#    {'trial_id': 'p8Yto'},
#    {'trial_id': 'HTgjo'},
#    {'trial_id': 'HTgjo'},
#    {'trial_id': 'HTgjo'},
#    {'trial_id': 'mz4K4'},
#    {'trial_id': 'mz4K4'},
#    {'trial_id': 'mz4K4'},
#    {'trial_id': 'j9Fn6'},
#    {'trial_id': 'j9Fn6'},
#    {'trial_id': 'j9Fn6'},
#    {'trial_id': 'eWMbj'},
#    {'trial_id': 'eWMbj'},
#    {'trial_id': 'eWMbj'},
#    {'trial_id': 'BfxeZ'},
#    {'trial_id': 'BfxeZ'},
#    {'trial_id': 'BfxeZ'},
#    {'trial_id': 'scJJC'},
#    {'trial_id': 'scJJC'},
#    {'trial_id': 'scJJC'},
#    {'trial_id': 'eHJGE'},
#    {'trial_id': 'eHJGE'},
#    {'trial_id': 'eHJGE'},
#    {'trial_id': 'pxYot'},
#    {'trial_id': 'pxYot'},
#    {'trial_id': 'pxYot'},
#    {'trial_id': 'iEkak'},
#    {'trial_id': 'iEkak'},
#    {'trial_id': 'iEkak'},
#    {'trial_id': 'FdLig'},
#    {'trial_id': 'FdLig'},
#    {'trial_id': 'FdLig'},
#    {'trial_id': 'y15Hj'},
#    {'trial_id': 'y15Hj'},
#    {'trial_id': 'y15Hj'},
#    {'trial_id': 'rjgcY'},
#    {'trial_id': 'rjgcY'},
#    {'trial_id': 'rjgcY'},
#    {'trial_id': 'WZ5jb'},
#    {'trial_id': 'WZ5jb'},
#    {'trial_id': 'WZ5jb'},
#    {'trial_id': 'BwRPF'},
#    {'trial_id': 'BwRPF'},
#    {'trial_id': 'BwRPF'},
#    {'trial_id': 'jTh9C'},
#    {'trial_id': 'jTh9C'},
#    {'trial_id': 'jTh9C'},
#    {'trial_id': 'eAIVL'},
#    {'trial_id': 'eAIVL'},
#    {'trial_id': 'eAIVL'},
#    {'trial_id': 'zJIfW'},
#    {'trial_id': 'zJIfW'},
#    {'trial_id': 'zJIfW'},
#    {'trial_id': 'PvQH0'},
#    {'trial_id': 'PvQH0'},
#    {'trial_id': 'PvQH0'},
#    {'trial_id': 'wL2Sz'},
#    {'trial_id': 'wL2Sz'},
#    {'trial_id': 'wL2Sz'},
#    {'trial_id': 'BJ8cT'},
#    {'trial_id': 'BJ8cT'},
#    {'trial_id': 'BJ8cT'},
#    {'trial_id': 'IvIwx'},
#    {'trial_id': 'IvIwx'},
#    {'trial_id': 'IvIwx'},
#    {'trial_id': 'L5p6F'},
#    {'trial_id': 'L5p6F'},
#    {'trial_id': 'L5p6F'},
#    {'trial_id': 'PLDaJ'},
#    {'trial_id': 'PLDaJ'},
#    {'trial_id': 'PLDaJ'},
#    {'trial_id': 'wsdxk'},
#    {'trial_id': 'wsdxk'},
#    {'trial_id': 'wsdxk'}],
#   'method': 'TPE'},
#  'fd50fhVE': {'trials': [{'trial_id': 'G7JEP'},
#    {'trial_id': 'G7JEP'},
#    {'trial_id': 'G7JEP'},
#    {'trial_id': 'hKjLO'},
#    {'trial_id': 'hKjLO'},
#    {'trial_id': 'hKjLO'},
#    {'trial_id': 'TPKNG'},
#    {'trial_id': 'TPKNG'},
#    {'trial_id': 'TPKNG'},
#    {'trial_id': 'FCzpX'},
#    {'trial_id': 'FCzpX'},
#    {'trial_id': 'FCzpX'},
#    {'trial_id': 'bReTn'},
#    {'trial_id': 'bReTn'},
#    {'trial_id': 'bReTn'},
#    {'trial_id': 'pxLeo'},
#    {'trial_id': 'pxLeo'},
#    {'trial_id': 'pxLeo'},
#    {'trial_id': 'ipK8X'},
#    {'trial_id': 'ipK8X'},
#    {'trial_id': 'ipK8X'},
#    {'trial_id': 'PQkD1'},
#    {'trial_id': 'PQkD1'},
#    {'trial_id': 'PQkD1'},
#    {'trial_id': 'QBY7M'},
#    {'trial_id': 'QBY7M'},
#    {'trial_id': 'QBY7M'},
#    {'trial_id': 'wHR8E'},
#    {'trial_id': 'wHR8E'},
#    {'trial_id': 'wHR8E'},
#    {'trial_id': 'pgPGI'},
#    {'trial_id': 'pgPGI'},
#    {'trial_id': 'pgPGI'},
#    {'trial_id': 'IIFmv'},
#    {'trial_id': 'IIFmv'},
#    {'trial_id': 'IIFmv'},
#    {'trial_id': 'jrSoQ'},
#    {'trial_id': 'jrSoQ'},
#    {'trial_id': 'jrSoQ'},
#    {'trial_id': 'rpQrP'},
#    {'trial_id': 'rpQrP'},
#    {'trial_id': 'rpQrP'},
#    {'trial_id': 'uWntp'},
#    {'trial_id': 'uWntp'},
#    {'trial_id': 'uWntp'},
#    {'trial_id': 'H6y3V'},
#    {'trial_id': 'H6y3V'},
#    {'trial_id': 'H6y3V'},
#    {'trial_id': 'Uvmsb'},
#    {'trial_id': 'Uvmsb'},
#    {'trial_id': 'Uvmsb'},
#    {'trial_id': 'HlJJ7'},
#    {'trial_id': 'HlJJ7'},
#    {'trial_id': 'HlJJ7'},
#    {'trial_id': 'YZRRP'},
#    {'trial_id': 'YZRRP'},
#    {'trial_id': 'YZRRP'},
#    {'trial_id': 'ZewJq'},
#    {'trial_id': 'ZewJq'},
#    {'trial_id': 'ZewJq'},
#    {'trial_id': 'dFhen'},
#    {'trial_id': 'dFhen'},
#    {'trial_id': 'dFhen'},
#    {'trial_id': 'uwkYX'},
#    {'trial_id': 'uwkYX'},
#    {'trial_id': 'uwkYX'},
#    {'trial_id': 'lDDca'},
#    {'trial_id': 'lDDca'},
#    {'trial_id': 'lDDca'},
#    {'trial_id': 'NiGbH'},
#    {'trial_id': 'NiGbH'},
#    {'trial_id': 'NiGbH'},
#    {'trial_id': 'CXX9s'},
#    {'trial_id': 'CXX9s'},
#    {'trial_id': 'CXX9s'},
#    {'trial_id': 'NhB7p'},
#    {'trial_id': 'NhB7p'},
#    {'trial_id': 'NhB7p'},
#    {'trial_id': 'q75oL'},
#    {'trial_id': 'q75oL'},
#    {'trial_id': 'q75oL'},
#    {'trial_id': 'lcbzw'},
#    {'trial_id': 'lcbzw'},
#    {'trial_id': 'lcbzw'},
#    {'trial_id': 'oxpeR'},
#    {'trial_id': 'oxpeR'},
#    {'trial_id': 'oxpeR'},
#    {'trial_id': 'YhgmJ'},
#    {'trial_id': 'YhgmJ'},
#    {'trial_id': 'YhgmJ'}],
#   'method': 'MetisTuner'},
#  'bYre8Qbc': {'trials': [{'trial_id': 'e4OR1'},
#    {'trial_id': 'e4OR1'},
#    {'trial_id': 'e4OR1'},
#    {'trial_id': 'DW29N'},
#    {'trial_id': 'DW29N'},
#    {'trial_id': 'DW29N'},
#    {'trial_id': 'IjJqq'},
#    {'trial_id': 'IjJqq'},
#    {'trial_id': 'IjJqq'},
#    {'trial_id': 'jjwms'},
#    {'trial_id': 'jjwms'},
#    {'trial_id': 'jjwms'},
#    {'trial_id': 'BD2xd'},
#    {'trial_id': 'BD2xd'},
#    {'trial_id': 'BD2xd'},
#    {'trial_id': 'NeAoq'},
#    {'trial_id': 'NeAoq'},
#    {'trial_id': 'NeAoq'},
#    {'trial_id': 'BLa9l'},
#    {'trial_id': 'BLa9l'},
#    {'trial_id': 'BLa9l'},
#    {'trial_id': 'U5Qvl'},
#    {'trial_id': 'U5Qvl'},
#    {'trial_id': 'U5Qvl'},
#    {'trial_id': 'bP4p1'},
#    {'trial_id': 'bP4p1'},
#    {'trial_id': 'bP4p1'},
#    {'trial_id': 'k8Lyx'},
#    {'trial_id': 'k8Lyx'},
#    {'trial_id': 'k8Lyx'},
#    {'trial_id': 'SlLzy'},
#    {'trial_id': 'SlLzy'},
#    {'trial_id': 'SlLzy'},
#    {'trial_id': 'fDv92'},
#    {'trial_id': 'fDv92'},
#    {'trial_id': 'fDv92'},
#    {'trial_id': 'obcR9'},
#    {'trial_id': 'obcR9'},
#    {'trial_id': 'obcR9'},
#    {'trial_id': 'beHdd'},
#    {'trial_id': 'beHdd'},
#    {'trial_id': 'beHdd'},
#    {'trial_id': 'JJkMC'},
#    {'trial_id': 'JJkMC'},
#    {'trial_id': 'JJkMC'},
#    {'trial_id': 'Cq0t2'},
#    {'trial_id': 'Cq0t2'},
#    {'trial_id': 'Cq0t2'},
#    {'trial_id': 'opOCh'},
#    {'trial_id': 'opOCh'},
#    {'trial_id': 'opOCh'},
#    {'trial_id': 'vyDib'},
#    {'trial_id': 'vyDib'},
#    {'trial_id': 'vyDib'},
#    {'trial_id': 'Op6u8'},
#    {'trial_id': 'Op6u8'},
#    {'trial_id': 'Op6u8'},
#    {'trial_id': 'Vnh0L'},
#    {'trial_id': 'Vnh0L'},
#    {'trial_id': 'Vnh0L'},
#    {'trial_id': 'Gymzn'},
#    {'trial_id': 'Gymzn'},
#    {'trial_id': 'Gymzn'},
#    {'trial_id': 'dChvc'},
#    {'trial_id': 'dChvc'},
#    {'trial_id': 'dChvc'},
#    {'trial_id': 'MGSD7'},
#    {'trial_id': 'MGSD7'},
#    {'trial_id': 'MGSD7'},
#    {'trial_id': 'EivU7'},
#    {'trial_id': 'EivU7'},
#    {'trial_id': 'EivU7'},
#    {'trial_id': 'NavLD'},
#    {'trial_id': 'NavLD'},
#    {'trial_id': 'NavLD'},
#    {'trial_id': 'dlVhc'},
#    {'trial_id': 'dlVhc'},
#    {'trial_id': 'dlVhc'},
#    {'trial_id': 'MDUvs'},
#    {'trial_id': 'MDUvs'},
#    {'trial_id': 'MDUvs'},
#    {'trial_id': 'umRUs'},
#    {'trial_id': 'umRUs'},
#    {'trial_id': 'umRUs'},
#    {'trial_id': 'Sg2tA'},
#    {'trial_id': 'Sg2tA'},
#    {'trial_id': 'Sg2tA'},
#    {'trial_id': 'oBOww'},
#    {'trial_id': 'oBOww'},
#    {'trial_id': 'oBOww'}],
#   'method': 'Anneal'},
#  'uvckVe1K': {'trials': [{'trial_id': 'S4kxF'},
#    {'trial_id': 'S4kxF'},
#    {'trial_id': 'S4kxF'},
#    {'trial_id': 'LU5cM'},
#    {'trial_id': 'LU5cM'},
#    {'trial_id': 'LU5cM'},
#    {'trial_id': 'AzUF7'},
#    {'trial_id': 'AzUF7'},
#    {'trial_id': 'AzUF7'},
#    {'trial_id': 'pwsQ5'},
#    {'trial_id': 'pwsQ5'},
#    {'trial_id': 'pwsQ5'},
#    {'trial_id': 'ttoZ3'},
#    {'trial_id': 'ttoZ3'},
#    {'trial_id': 'ttoZ3'},
#    {'trial_id': 'k5BOo'},
#    {'trial_id': 'k5BOo'},
#    {'trial_id': 'k5BOo'},
#    {'trial_id': 'jwq6p'},
#    {'trial_id': 'jwq6p'},
#    {'trial_id': 'jwq6p'},
#    {'trial_id': 'XPKXM'},
#    {'trial_id': 'XPKXM'},
#    {'trial_id': 'XPKXM'},
#    {'trial_id': 'OqtDQ'},
#    {'trial_id': 'OqtDQ'},
#    {'trial_id': 'OqtDQ'},
#    {'trial_id': 'S0nUc'},
#    {'trial_id': 'S0nUc'},
#    {'trial_id': 'S0nUc'},
#    {'trial_id': 'UfW0q'},
#    {'trial_id': 'UfW0q'},
#    {'trial_id': 'UfW0q'},
#    {'trial_id': 'hSXH9'},
#    {'trial_id': 'hSXH9'},
#    {'trial_id': 'hSXH9'},
#    {'trial_id': 'F0svS'},
#    {'trial_id': 'F0svS'},
#    {'trial_id': 'F0svS'},
#    {'trial_id': 'IKzVR'},
#    {'trial_id': 'IKzVR'},
#    {'trial_id': 'IKzVR'},
#    {'trial_id': 'tEVpV'},
#    {'trial_id': 'tEVpV'},
#    {'trial_id': 'tEVpV'},
#    {'trial_id': 'l8jZA'},
#    {'trial_id': 'l8jZA'},
#    {'trial_id': 'l8jZA'},
#    {'trial_id': 'BZeVO'},
#    {'trial_id': 'BZeVO'},
#    {'trial_id': 'BZeVO'},
#    {'trial_id': 'xxoFz'},
#    {'trial_id': 'xxoFz'},
#    {'trial_id': 'xxoFz'},
#    {'trial_id': 'RXxRw'},
#    {'trial_id': 'RXxRw'},
#    {'trial_id': 'RXxRw'},
#    {'trial_id': 'UpHQ4'},
#    {'trial_id': 'UpHQ4'},
#    {'trial_id': 'UpHQ4'},
#    {'trial_id': 'Cq4Iz'},
#    {'trial_id': 'Cq4Iz'},
#    {'trial_id': 'Cq4Iz'},
#    {'trial_id': 'RVXsh'},
#    {'trial_id': 'RVXsh'},
#    {'trial_id': 'RVXsh'},
#    {'trial_id': 'baIA7'},
#    {'trial_id': 'baIA7'},
#    {'trial_id': 'baIA7'},
#    {'trial_id': 'D0HPo'},
#    {'trial_id': 'D0HPo'},
#    {'trial_id': 'D0HPo'},
#    {'trial_id': 'HKFpn'},
#    {'trial_id': 'HKFpn'},
#    {'trial_id': 'HKFpn'},
#    {'trial_id': 'c1pFt'},
#    {'trial_id': 'c1pFt'},
#    {'trial_id': 'c1pFt'},
#    {'trial_id': 'AV6Ch'},
#    {'trial_id': 'AV6Ch'},
#    {'trial_id': 'AV6Ch'},
#    {'trial_id': 'AlP9i'},
#    {'trial_id': 'AlP9i'},
#    {'trial_id': 'AlP9i'},
#    {'trial_id': 'sAmoR'},
#    {'trial_id': 'sAmoR'},
#    {'trial_id': 'sAmoR'},
#    {'trial_id': 'au9Ec'},
#    {'trial_id': 'au9Ec'},
#    {'trial_id': 'au9Ec'}],
#   'method': 'GridSearch'},
#  'pdeV6FAp': {'trials': [{'trial_id': 'CZaRi'},
#    {'trial_id': 'CZaRi'},
#    {'trial_id': 'CZaRi'},
#    {'trial_id': 'mo8EC'},
#    {'trial_id': 'mo8EC'},
#    {'trial_id': 'mo8EC'},
#    {'trial_id': 'TKQRt'},
#    {'trial_id': 'TKQRt'},
#    {'trial_id': 'TKQRt'},
#    {'trial_id': 'VFzdr'},
#    {'trial_id': 'VFzdr'},
#    {'trial_id': 'VFzdr'},
#    {'trial_id': 'wQtJi'},
#    {'trial_id': 'wQtJi'},
#    {'trial_id': 'wQtJi'},
#    {'trial_id': 'PxreC'},
#    {'trial_id': 'PxreC'},
#    {'trial_id': 'PxreC'},
#    {'trial_id': 'qLq9R'},
#    {'trial_id': 'qLq9R'},
#    {'trial_id': 'qLq9R'},
#    {'trial_id': 'jjcTn'},
#    {'trial_id': 'jjcTn'},
#    {'trial_id': 'jjcTn'},
#    {'trial_id': 'aBcmx'},
#    {'trial_id': 'aBcmx'},
#    {'trial_id': 'aBcmx'},
#    {'trial_id': 'bqSWX'},
#    {'trial_id': 'bqSWX'},
#    {'trial_id': 'bqSWX'},
#    {'trial_id': 'q6nHm'},
#    {'trial_id': 'q6nHm'},
#    {'trial_id': 'q6nHm'},
#    {'trial_id': 'xUtqE'},
#    {'trial_id': 'xUtqE'},
#    {'trial_id': 'xUtqE'},
#    {'trial_id': 'A9BFr'},
#    {'trial_id': 'A9BFr'},
#    {'trial_id': 'A9BFr'},
#    {'trial_id': 'KxX1P'},
#    {'trial_id': 'KxX1P'},
#    {'trial_id': 'KxX1P'},
#    {'trial_id': 'pKPtO'},
#    {'trial_id': 'pKPtO'},
#    {'trial_id': 'pKPtO'},
#    {'trial_id': 'H2WyL'},
#    {'trial_id': 'H2WyL'},
#    {'trial_id': 'H2WyL'},
#    {'trial_id': 'aMmsp'},
#    {'trial_id': 'aMmsp'},
#    {'trial_id': 'aMmsp'},
#    {'trial_id': 'QQcBL'},
#    {'trial_id': 'QQcBL'},
#    {'trial_id': 'QQcBL'},
#    {'trial_id': 'jGJjJ'},
#    {'trial_id': 'jGJjJ'},
#    {'trial_id': 'jGJjJ'},
#    {'trial_id': 'FDGme'},
#    {'trial_id': 'FDGme'},
#    {'trial_id': 'FDGme'},
#    {'trial_id': 'B7rQm'},
#    {'trial_id': 'B7rQm'},
#    {'trial_id': 'B7rQm'},
#    {'trial_id': 'E1RUF'},
#    {'trial_id': 'E1RUF'},
#    {'trial_id': 'E1RUF'},
#    {'trial_id': 'soW7w'},
#    {'trial_id': 'soW7w'},
#    {'trial_id': 'soW7w'},
#    {'trial_id': 'hOoh8'},
#    {'trial_id': 'hOoh8'},
#    {'trial_id': 'hOoh8'},
#    {'trial_id': 'alIsX'},
#    {'trial_id': 'alIsX'},
#    {'trial_id': 'alIsX'},
#    {'trial_id': 'jwyTT'},
#    {'trial_id': 'jwyTT'},
#    {'trial_id': 'jwyTT'},
#    {'trial_id': 'EgNWx'},
#    {'trial_id': 'EgNWx'},
#    {'trial_id': 'EgNWx'},
#    {'trial_id': 'Etfu2'},
#    {'trial_id': 'Etfu2'},
#    {'trial_id': 'Etfu2'},
#    {'trial_id': 'VmkoT'},
#    {'trial_id': 'VmkoT'},
#    {'trial_id': 'VmkoT'},
#    {'trial_id': 'UPnvz'},
#    {'trial_id': 'UPnvz'},
#    {'trial_id': 'UPnvz'}],
#   'method': 'Random'},
#  'aUbMNLkd': {'trials': [{'trial_id': 'jqxmU'},
#    {'trial_id': 'jqxmU'},
#    {'trial_id': 'jqxmU'},
#    {'trial_id': 'bawBu'},
#    {'trial_id': 'bawBu'},
#    {'trial_id': 'bawBu'},
#    {'trial_id': 'IRf4w'},
#    {'trial_id': 'IRf4w'},
#    {'trial_id': 'IRf4w'},
#    {'trial_id': 'I9JXx'},
#    {'trial_id': 'I9JXx'},
#    {'trial_id': 'I9JXx'},
#    {'trial_id': 'xCHwz'},
#    {'trial_id': 'xCHwz'},
#    {'trial_id': 'xCHwz'},
#    {'trial_id': 'DjTUc'},
#    {'trial_id': 'DjTUc'},
#    {'trial_id': 'DjTUc'},
#    {'trial_id': 'yD80P'},
#    {'trial_id': 'yD80P'},
#    {'trial_id': 'yD80P'},
#    {'trial_id': 'R54Zs'},
#    {'trial_id': 'R54Zs'},
#    {'trial_id': 'R54Zs'},
#    {'trial_id': 'gtsPW'},
#    {'trial_id': 'gtsPW'},
#    {'trial_id': 'gtsPW'},
#    {'trial_id': 'n3KVu'},
#    {'trial_id': 'n3KVu'},
#    {'trial_id': 'n3KVu'},
#    {'trial_id': 'eWS0z'},
#    {'trial_id': 'eWS0z'},
#    {'trial_id': 'eWS0z'},
#    {'trial_id': 'jB49p'},
#    {'trial_id': 'jB49p'},
#    {'trial_id': 'jB49p'},
#    {'trial_id': 'QZbCs'},
#    {'trial_id': 'QZbCs'},
#    {'trial_id': 'QZbCs'},
#    {'trial_id': 'tKTwR'},
#    {'trial_id': 'tKTwR'},
#    {'trial_id': 'tKTwR'},
#    {'trial_id': 'i2Z8f'},
#    {'trial_id': 'i2Z8f'},
#    {'trial_id': 'i2Z8f'},
#    {'trial_id': 'qOsbG'},
#    {'trial_id': 'qOsbG'},
#    {'trial_id': 'qOsbG'},
#    {'trial_id': 'dfEES'},
#    {'trial_id': 'dfEES'},
#    {'trial_id': 'dfEES'},
#    {'trial_id': 'G3Vrx'},
#    {'trial_id': 'G3Vrx'},
#    {'trial_id': 'G3Vrx'},
#    {'trial_id': 'AmGYP'},
#    {'trial_id': 'AmGYP'},
#    {'trial_id': 'AmGYP'},
#    {'trial_id': 'd8hBy'},
#    {'trial_id': 'd8hBy'},
#    {'trial_id': 'd8hBy'},
#    {'trial_id': 'bbjZc'},
#    {'trial_id': 'bbjZc'},
#    {'trial_id': 'bbjZc'},
#    {'trial_id': 'E2FOW'},
#    {'trial_id': 'E2FOW'},
#    {'trial_id': 'E2FOW'},
#    {'trial_id': 'ggCLW'},
#    {'trial_id': 'ggCLW'},
#    {'trial_id': 'ggCLW'},
#    {'trial_id': 'PiApu'},
#    {'trial_id': 'PiApu'},
#    {'trial_id': 'PiApu'},
#    {'trial_id': 'gY0tr'},
#    {'trial_id': 'gY0tr'},
#    {'trial_id': 'gY0tr'},
#    {'trial_id': 'IdodQ'},
#    {'trial_id': 'IdodQ'},
#    {'trial_id': 'IdodQ'},
#    {'trial_id': 'f3rVm'},
#    {'trial_id': 'f3rVm'},
#    {'trial_id': 'f3rVm'},
#    {'trial_id': 'a7Qw6'},
#    {'trial_id': 'a7Qw6'},
#    {'trial_id': 'a7Qw6'},
#    {'trial_id': 'Thwqp'},
#    {'trial_id': 'Thwqp'},
#    {'trial_id': 'Thwqp'},
#    {'trial_id': 'WdEfP'},
#    {'trial_id': 'WdEfP'},
#    {'trial_id': 'WdEfP'}],
#   'method': 'PBTTuner'},
#  'eiJBCWXC': {'trials': [{'trial_id': 'nJDEu'},
#    {'trial_id': 'nJDEu'},
#    {'trial_id': 'nJDEu'},
#    {'trial_id': 'rubrs'},
#    {'trial_id': 'rubrs'},
#    {'trial_id': 'rubrs'},
#    {'trial_id': 'tZSIf'},
#    {'trial_id': 'tZSIf'},
#    {'trial_id': 'tZSIf'},
#    {'trial_id': 'U0Z6s'},
#    {'trial_id': 'U0Z6s'},
#    {'trial_id': 'U0Z6s'},
#    {'trial_id': 'sIAzl'},
#    {'trial_id': 'sIAzl'},
#    {'trial_id': 'sIAzl'},
#    {'trial_id': 'ByRma'},
#    {'trial_id': 'ByRma'},
#    {'trial_id': 'ByRma'},
#    {'trial_id': 'DoiD9'},
#    {'trial_id': 'DoiD9'},
#    {'trial_id': 'DoiD9'},
#    {'trial_id': 'gmTyd'},
#    {'trial_id': 'gmTyd'},
#    {'trial_id': 'gmTyd'},
#    {'trial_id': 'a76Zh'},
#    {'trial_id': 'a76Zh'},
#    {'trial_id': 'a76Zh'},
#    {'trial_id': 'gqiF7'},
#    {'trial_id': 'gqiF7'},
#    {'trial_id': 'gqiF7'},
#    {'trial_id': 'DMnUE'},
#    {'trial_id': 'DMnUE'},
#    {'trial_id': 'DMnUE'},
#    {'trial_id': 'KS1Em'},
#    {'trial_id': 'KS1Em'},
#    {'trial_id': 'KS1Em'},
#    {'trial_id': 'gaTkt'},
#    {'trial_id': 'gaTkt'},
#    {'trial_id': 'gaTkt'},
#    {'trial_id': 'yAo0Y'},
#    {'trial_id': 'yAo0Y'},
#    {'trial_id': 'yAo0Y'},
#    {'trial_id': 'gmRA0'},
#    {'trial_id': 'gmRA0'},
#    {'trial_id': 'gmRA0'},
#    {'trial_id': 'I1ggb'},
#    {'trial_id': 'I1ggb'},
#    {'trial_id': 'I1ggb'},
#    {'trial_id': 'yWtfg'},
#    {'trial_id': 'yWtfg'},
#    {'trial_id': 'yWtfg'},
#    {'trial_id': 'JZ21N'},
#    {'trial_id': 'JZ21N'},
#    {'trial_id': 'JZ21N'},
#    {'trial_id': 'DdidV'},
#    {'trial_id': 'DdidV'},
#    {'trial_id': 'DdidV'},
#    {'trial_id': 'AbAJD'},
#    {'trial_id': 'AbAJD'},
#    {'trial_id': 'AbAJD'},
#    {'trial_id': 'lf1PD'},
#    {'trial_id': 'lf1PD'},
#    {'trial_id': 'lf1PD'},
#    {'trial_id': 'TgNaw'},
#    {'trial_id': 'TgNaw'},
#    {'trial_id': 'TgNaw'},
#    {'trial_id': 'oP5fD'},
#    {'trial_id': 'oP5fD'},
#    {'trial_id': 'oP5fD'},
#    {'trial_id': 'nU2Bx'},
#    {'trial_id': 'nU2Bx'},
#    {'trial_id': 'nU2Bx'},
#    {'trial_id': 'CH9BW'},
#    {'trial_id': 'CH9BW'},
#    {'trial_id': 'CH9BW'},
#    {'trial_id': 'kIPSB'},
#    {'trial_id': 'kIPSB'},
#    {'trial_id': 'kIPSB'},
#    {'trial_id': 'Wfxo2'},
#    {'trial_id': 'Wfxo2'},
#    {'trial_id': 'Wfxo2'},
#    {'trial_id': 'vYY7e'},
#    {'trial_id': 'vYY7e'},
#    {'trial_id': 'vYY7e'},
#    {'trial_id': 'R1ya9'},
#    {'trial_id': 'R1ya9'},
#    {'trial_id': 'R1ya9'},
#    {'trial_id': 'wAbNz'},
#    {'trial_id': 'wAbNz'},
#    {'trial_id': 'wAbNz'}],
#   'method': 'Evolution'},
#  'XYhoDh6N': {'trials': [{'trial_id': 'v3Ckw'},
#    {'trial_id': 'v3Ckw'},
#    {'trial_id': 'v3Ckw'},
#    {'trial_id': 'lwTFC'},
#    {'trial_id': 'lwTFC'},
#    {'trial_id': 'lwTFC'},
#    {'trial_id': 'oCmBY'},
#    {'trial_id': 'oCmBY'},
#    {'trial_id': 'oCmBY'},
#    {'trial_id': 'ww8k7'},
#    {'trial_id': 'ww8k7'},
#    {'trial_id': 'ww8k7'},
#    {'trial_id': 'i4Doy'},
#    {'trial_id': 'i4Doy'},
#    {'trial_id': 'i4Doy'},
#    {'trial_id': 'JBgsm'},
#    {'trial_id': 'JBgsm'},
#    {'trial_id': 'JBgsm'},
#    {'trial_id': 'QAVWC'},
#    {'trial_id': 'QAVWC'},
#    {'trial_id': 'QAVWC'},
#    {'trial_id': 'ZsI3I'},
#    {'trial_id': 'ZsI3I'},
#    {'trial_id': 'ZsI3I'},
#    {'trial_id': 'B1U4G'},
#    {'trial_id': 'B1U4G'},
#    {'trial_id': 'B1U4G'},
#    {'trial_id': 'zWZvg'},
#    {'trial_id': 'zWZvg'},
#    {'trial_id': 'zWZvg'},
#    {'trial_id': 'D8ROP'},
#    {'trial_id': 'D8ROP'},
#    {'trial_id': 'D8ROP'},
#    {'trial_id': 'qzeb3'},
#    {'trial_id': 'qzeb3'},
#    {'trial_id': 'qzeb3'},
#    {'trial_id': 'wsMeo'},
#    {'trial_id': 'wsMeo'},
#    {'trial_id': 'wsMeo'},
#    {'trial_id': 'juytw'},
#    {'trial_id': 'juytw'},
#    {'trial_id': 'juytw'},
#    {'trial_id': 'wHkMW'},
#    {'trial_id': 'wHkMW'},
#    {'trial_id': 'wHkMW'},
#    {'trial_id': 'NAKJm'},
#    {'trial_id': 'NAKJm'},
#    {'trial_id': 'NAKJm'},
#    {'trial_id': 'GEi0i'},
#    {'trial_id': 'GEi0i'},
#    {'trial_id': 'GEi0i'},
#    {'trial_id': 'Dqepu'},
#    {'trial_id': 'Dqepu'},
#    {'trial_id': 'Dqepu'},
#    {'trial_id': 'Jue2h'},
#    {'trial_id': 'Jue2h'},
#    {'trial_id': 'Jue2h'},
#    {'trial_id': 'Rp994'},
#    {'trial_id': 'Rp994'},
#    {'trial_id': 'Rp994'},
#    {'trial_id': 'wAdXE'},
#    {'trial_id': 'wAdXE'},
#    {'trial_id': 'wAdXE'},
#    {'trial_id': 'z515R'},
#    {'trial_id': 'z515R'},
#    {'trial_id': 'z515R'},
#    {'trial_id': 'vekLD'},
#    {'trial_id': 'vekLD'},
#    {'trial_id': 'vekLD'},
#    {'trial_id': 'Kalen'},
#    {'trial_id': 'Kalen'},
#    {'trial_id': 'Kalen'},
#    {'trial_id': 'lZSXf'},
#    {'trial_id': 'lZSXf'},
#    {'trial_id': 'lZSXf'},
#    {'trial_id': 'jMMUV'},
#    {'trial_id': 'jMMUV'},
#    {'trial_id': 'jMMUV'},
#    {'trial_id': 'FzrW3'},
#    {'trial_id': 'FzrW3'},
#    {'trial_id': 'FzrW3'},
#    {'trial_id': 'fjqZU'},
#    {'trial_id': 'fjqZU'},
#    {'trial_id': 'fjqZU'},
#    {'trial_id': 'DAlVR'},
#    {'trial_id': 'DAlVR'},
#    {'trial_id': 'DAlVR'},
#    {'trial_id': 'ACfxv'},
#    {'trial_id': 'ACfxv'},
#    {'trial_id': 'ACfxv'}],
#   'method': 'GPTuner'},
#  'uRB7YVHl': {'trials': [{'trial_id': 'dUXCB'},
#    {'trial_id': 'dUXCB'},
#    {'trial_id': 'dUXCB'},
#    {'trial_id': 'mYCL9'},
#    {'trial_id': 'mYCL9'},
#    {'trial_id': 'mYCL9'},
#    {'trial_id': 'jfqGR'},
#    {'trial_id': 'jfqGR'},
#    {'trial_id': 'jfqGR'},
#    {'trial_id': 'uQaaq'},
#    {'trial_id': 'uQaaq'},
#    {'trial_id': 'uQaaq'},
#    {'trial_id': 'TCkQ1'},
#    {'trial_id': 'TCkQ1'},
#    {'trial_id': 'TCkQ1'},
#    {'trial_id': 'hDIEs'},
#    {'trial_id': 'hDIEs'},
#    {'trial_id': 'hDIEs'},
#    {'trial_id': 'DJgR6'},
#    {'trial_id': 'DJgR6'},
#    {'trial_id': 'DJgR6'},
#    {'trial_id': 'Toz8b'},
#    {'trial_id': 'Toz8b'},
#    {'trial_id': 'Toz8b'},
#    {'trial_id': 'qu7Cv'},
#    {'trial_id': 'qu7Cv'},
#    {'trial_id': 'qu7Cv'},
#    {'trial_id': 'kNzpk'},
#    {'trial_id': 'kNzpk'},
#    {'trial_id': 'kNzpk'},
#    {'trial_id': 'rq1WV'},
#    {'trial_id': 'rq1WV'},
#    {'trial_id': 'rq1WV'},
#    {'trial_id': 'QQqxq'},
#    {'trial_id': 'QQqxq'},
#    {'trial_id': 'QQqxq'},
#    {'trial_id': 'zU47V'},
#    {'trial_id': 'zU47V'},
#    {'trial_id': 'zU47V'},
#    {'trial_id': 'KqkgY'},
#    {'trial_id': 'KqkgY'},
#    {'trial_id': 'KqkgY'},
#    {'trial_id': 'MtTFS'},
#    {'trial_id': 'MtTFS'},
#    {'trial_id': 'MtTFS'},
#    {'trial_id': 'WfLKa'},
#    {'trial_id': 'WfLKa'},
#    {'trial_id': 'WfLKa'},
#    {'trial_id': 'nFXxj'},
#    {'trial_id': 'nFXxj'},
#    {'trial_id': 'nFXxj'},
#    {'trial_id': 'ttPEZ'},
#    {'trial_id': 'ttPEZ'},
#    {'trial_id': 'ttPEZ'},
#    {'trial_id': 'YEtNP'},
#    {'trial_id': 'YEtNP'},
#    {'trial_id': 'YEtNP'},
#    {'trial_id': 'mc6wW'},
#    {'trial_id': 'mc6wW'},
#    {'trial_id': 'mc6wW'},
#    {'trial_id': 'ZBZOE'},
#    {'trial_id': 'ZBZOE'},
#    {'trial_id': 'ZBZOE'},
#    {'trial_id': 'vfFpr'},
#    {'trial_id': 'vfFpr'},
#    {'trial_id': 'vfFpr'},
#    {'trial_id': 'bdr6K'},
#    {'trial_id': 'bdr6K'},
#    {'trial_id': 'bdr6K'},
#    {'trial_id': 'PiZyF'},
#    {'trial_id': 'PiZyF'},
#    {'trial_id': 'PiZyF'},
#    {'trial_id': 'LQaAy'},
#    {'trial_id': 'LQaAy'},
#    {'trial_id': 'LQaAy'},
#    {'trial_id': 'l5zBq'},
#    {'trial_id': 'l5zBq'},
#    {'trial_id': 'l5zBq'},
#    {'trial_id': 'vnJQB'},
#    {'trial_id': 'vnJQB'},
#    {'trial_id': 'vnJQB'},
#    {'trial_id': 'uxnUc'},
#    {'trial_id': 'uxnUc'},
#    {'trial_id': 'uxnUc'},
#    {'trial_id': 'zUUHH'},
#    {'trial_id': 'zUUHH'},
#    {'trial_id': 'zUUHH'},
#    {'trial_id': 'weWJZ'},
#    {'trial_id': 'weWJZ'},
#    {'trial_id': 'weWJZ'}],
#   'method': 'SMAC'},
#  'SreqCz44': {'trials': [{'trial_id': 'IufvK'},
#    {'trial_id': 'IufvK'},
#    {'trial_id': 'IufvK'},
#    {'trial_id': 'bqHcA'},
#    {'trial_id': 'bqHcA'},
#    {'trial_id': 'bqHcA'},
#    {'trial_id': 'Jo61h'},
#    {'trial_id': 'Jo61h'},
#    {'trial_id': 'Jo61h'},
#    {'trial_id': 'VzYfc'},
#    {'trial_id': 'VzYfc'},
#    {'trial_id': 'VzYfc'},
#    {'trial_id': 'JavVX'},
#    {'trial_id': 'JavVX'},
#    {'trial_id': 'JavVX'},
#    {'trial_id': 'RMHeM'},
#    {'trial_id': 'RMHeM'},
#    {'trial_id': 'RMHeM'},
#    {'trial_id': 'mgqhC'},
#    {'trial_id': 'mgqhC'},
#    {'trial_id': 'mgqhC'},
#    {'trial_id': 'beoOs'},
#    {'trial_id': 'beoOs'},
#    {'trial_id': 'beoOs'},
#    {'trial_id': 'SLKOM'},
#    {'trial_id': 'SLKOM'},
#    {'trial_id': 'SLKOM'},
#    {'trial_id': 'ZPqKx'},
#    {'trial_id': 'ZPqKx'},
#    {'trial_id': 'ZPqKx'},
#    {'trial_id': 'vOPtr'},
#    {'trial_id': 'vOPtr'},
#    {'trial_id': 'vOPtr'},
#    {'trial_id': 'ICyWz'},
#    {'trial_id': 'ICyWz'},
#    {'trial_id': 'ICyWz'},
#    {'trial_id': 'Gdh6P'},
#    {'trial_id': 'Gdh6P'},
#    {'trial_id': 'Gdh6P'},
#    {'trial_id': 'hl8t9'},
#    {'trial_id': 'hl8t9'},
#    {'trial_id': 'hl8t9'},
#    {'trial_id': 'wC9Up'},
#    {'trial_id': 'wC9Up'},
#    {'trial_id': 'wC9Up'},
#    {'trial_id': 'h6Vor'},
#    {'trial_id': 'h6Vor'},
#    {'trial_id': 'h6Vor'},
#    {'trial_id': 'PFTFD'},
#    {'trial_id': 'PFTFD'},
#    {'trial_id': 'PFTFD'},
#    {'trial_id': 'ovqD8'},
#    {'trial_id': 'ovqD8'},
#    {'trial_id': 'ovqD8'},
#    {'trial_id': 'eWeR6'},
#    {'trial_id': 'eWeR6'},
#    {'trial_id': 'eWeR6'},
#    {'trial_id': 'vXS6r'},
#    {'trial_id': 'vXS6r'},
#    {'trial_id': 'vXS6r'},
#    {'trial_id': 'f8ctG'},
#    {'trial_id': 'f8ctG'},
#    {'trial_id': 'f8ctG'},
#    {'trial_id': 'lfTek'},
#    {'trial_id': 'lfTek'},
#    {'trial_id': 'lfTek'},
#    {'trial_id': 'zIDya'},
#    {'trial_id': 'zIDya'},
#    {'trial_id': 'zIDya'},
#    {'trial_id': 'AFF5e'},
#    {'trial_id': 'AFF5e'},
#    {'trial_id': 'AFF5e'},
#    {'trial_id': 'OZ5VH'},
#    {'trial_id': 'OZ5VH'},
#    {'trial_id': 'OZ5VH'},
#    {'trial_id': 'HCKEE'},
#    {'trial_id': 'HCKEE'},
#    {'trial_id': 'HCKEE'},
#    {'trial_id': 'R2Ita'},
#    {'trial_id': 'R2Ita'},
#    {'trial_id': 'R2Ita'},
#    {'trial_id': 'YZFbY'},
#    {'trial_id': 'YZFbY'},
#    {'trial_id': 'YZFbY'},
#    {'trial_id': 'TDSw3'},
#    {'trial_id': 'TDSw3'},
#    {'trial_id': 'TDSw3'},
#    {'trial_id': 'WVDEn'},
#    {'trial_id': 'WVDEn'},
#    {'trial_id': 'WVDEn'}],
#   'method': 'Hyperband'}}
